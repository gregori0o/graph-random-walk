# %%
import networkx as nx
from nonlinear_walk import NonlinearRandomWalk

# %%
G = nx.karate_club_graph()
graph_walk = NonlinearRandomWalk(G)

# %%
graph_walk.get_visualization()
# Out:
# /home/glegeza/Programming/semestr2/graph-random-walk/nonlinear_walk.py:92: UserWarning: frames=<generator object NonlinearRandomWalk.simulate at 0x7efee6496880> which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(

# %%
graph_walk.calculate_for_alphas()

# %%
graph_walk.plot_for_alphas([0, 1, 2, 3, 33])
