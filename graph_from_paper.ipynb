# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
def draw_graph(G):
    pos = nx.circular_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size=400)
    nx.draw_networkx_edges(G, pos, width=1)
    plt.axis('off')
    plt.show()

# %%
G = nx.Graph()
G.add_nodes_from(range(8))
G.add_edges_from([(0, 3), (1, 2), (1, 4), (2, 3), (2, 7), (3, 5), (5, 6), (6, 7)])

# %%
draw_graph(G)

# %%
from nonlinear_walk import NonlinearRandomWalk

# %%
graph_walk = NonlinearRandomWalk(G)
# graph_walk.get_visualization(alpha=2)

# %%
graph_walk.calculate_for_alphas(-6, 6, 200, tol=1e-6, max_iter=1000)

# %%
graph_walk.plot_for_alphas()

# %%
graph_walk.plot_for_alphas([3, 4])
